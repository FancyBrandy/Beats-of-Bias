# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

dsongs = pd.read_csv('/content/drive/MyDrive/Praktikum - NLP Applications/Datasets/genius_and_wasabi/concatenated_chunks.csv', low_memory=False)
list(dsongs.columns)
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'title',
#  'genre',
#  'artist',
#  'year',
#  'views',
#  'features',
#  'lyrics',
#  'language',
#  'gender']

# %%
print(len(dsongs))
# Out:
# 537553

# %%
dsongs[["genre"]].value_counts()
# Out:
# genre
# pop        311085
# rap         94234
# rock        54560
# country     39078
# rb          30747
# misc         7849
# dtype: int64

# %%
drock_songs = dsongs[dsongs['genre'] == 'rock']
print(len(drock_songs))
# Out:
# 54560

# %%
dsongs[["year"]].value_counts()
# Out:
# year
# 2015    71489
# 2013    20351
# 2011    19211
# 2012    18685
# 2014    17741
#         ...
# 1803        1
# 1802        1
# 1791        1
# 1790        1
# 1808        1
# Length: 196, dtype: int64

# %%
listof90s = [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999]
dninetys_songs = dsongs[dsongs['year'].isin(listof90s)]
print(len(dninetys_songs))
# Out:
# 63493

# %%
path = '/content/drive/MyDrive/Praktikum - NLP Applications/Datasets/genius_and_wasabi/'

fdata_path_for_genre = path + 'rock_genre_songs.csv'
data_path_for_decade = path + '90s_decade_songs.csv'

drock_songs.to_csv(data_path_for_genre)
dninetys_songs.to_csv(data_path_for_decade)
