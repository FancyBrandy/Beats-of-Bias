# %% [markdown]
# WEAT Analysis for Bias Measurements of Lyrics
#
# Dictionary of attribute and target sets obtained from: https://github.com/Loreb92/sexism_and_bias_in_song_lyrics/blob/main/
#
# Path to dictionary of words: data/Data_WEAT/weat_attrib_target_3.json

# %%
from google.colab import drive
import os

  # gdrive_path='/content/gdrive/MyDrive/Bertopic/shared_work/'

  # # This will mount your google drive under 'MyDrive'
# drive.mount('/content/gdrive', force_remount=True)
# # In order to access the files in this notebook we have to navigate to the correct folder
# os.chdir(gdrive_path)
# dataset_path = ''
# # Check manually if all files are present
# print(sorted(os.listdir()))

# To run from the common drive:
dataset_path = '/content/drive/MyDrive/Praktikum - NLP Applications/Models/bertopic_concatenated_chunks_stratified'
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import re
import time
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from gensim.models import Word2Vec, KeyedVectors
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
embeddings_path = '/content/drive/MyDrive/Praktikum - NLP Applications/WEAT/embeddings/'
csv_file_path = '/results/topics_for_bias_analysis.csv'

df = pd.read_csv(dataset_path + csv_file_path)
data = df[df['topic'] != -1]
data = data[data['genre'] != 'misc']

# %%
wordset_path = '/content/drive/MyDrive/Praktikum - NLP Applications/WEAT/betti2023_weat_wordsets.csv'
wordsets = pd.read_csv(wordset_path)

# %%
wordsets.head()
# Out:
#                   set_name                                              words
# 0   African American names  ['shavonn', 'yolanda', 'torrance', 'jerome', '...
# 1         Appearance words  ['sensual', 'thin', 'handsome', 'feeble', 'bal...
# 2               Arts words  ['shakespeare', 'symphony', 'literature', 'poe...
# 3             Career words  ['business', 'corporation', 'career', 'salary'...
# 4  European American names  ['jay', 'melanie', 'justin', 'stephanie', 'ada...

# %%
male_words = ['he', 'him', 'his', 'father', 'papa', 'dad', 'son', 'uncle', 'grandfather', 'grandpa', 'man', 'male', 'brother', 'husband', 'boyfriend', 'sir', 'king', 'guy', 'father-in-law', 'son-in-law', 'nephew', 'boy']
female_words = ['she', 'her', 'hers', 'mother', 'mama', 'daughter', 'aunt', 'auntie', 'grandmother', 'woman', 'female', 'sister', 'mom', 'wife', 'girlfriend', 'madam', 'queen', 'gal', 'niece', 'grandmother-in-law', 'daughter-in-law', 'lady', 'miss', 'sis', 'girl']

# %%
import ast

male_set = wordsets[wordsets['set_name'] == 'Male attributes']['words'].tolist()[0]
male_set = ast.literal_eval(male_set)
male_attribute_set = set(male_set).union(set(male_words))

male_attribute_set
# male_set[0]
# Out:
# {'boy',
#  'boyfriend',
#  'brother',
#  'dad',
#  'father',
#  'father-in-law',
#  'grandfather',
#  'grandpa',
#  'guy',
#  'he',
#  'him',
#  'his',
#  'husband',
#  'king',
#  'male',
#  'man',
#  'nephew',
#  'papa',
#  'sir',
#  'son',
#  'son-in-law',
#  'uncle'}

# %%
female_set = wordsets[wordsets['set_name'] == 'Female attributes']['words'].tolist()[0]
female_set = ast.literal_eval(female_set)
female_attribute_set = set(female_set).union(set(female_words))

female_attribute_set
# Out:
# {'aunt',
#  'auntie',
#  'daughter',
#  'daughter-in-law',
#  'female',
#  'gal',
#  'girl',
#  'girlfriend',
#  'grandmother',
#  'grandmother-in-law',
#  'her',
#  'hers',
#  'lady',
#  'madam',
#  'mama',
#  'miss',
#  'mom',
#  'mother',
#  'niece',
#  'queen',
#  'she',
#  'sis',
#  'sister',
#  'wife',
#  'woman'}

# %%
target_sets = ['Pleasant', 'Unpleasant', 'Appearance words', 'Intelligence words', 'Strenght words', 'Weakness words']

ast.literal_eval(wordsets[wordsets['set_name'] == target_sets[0]]['words'].tolist()[0])
# Out:
# ['friend',
#  'joy',
#  'wonderful',
#  'vacation',
#  'love',
#  'honest',
#  'honor',
#  'pleasure',
#  'loyal',
#  'family',
#  'peace',
#  'heaven',
#  'cheer',
#  'freedom',
#  'diploma',
#  'gentle',
#  'happy',
#  'paradise',
#  'diamond',
#  'laughter',
#  'sunrise',
#  'gift',
#  'health',
#  'rainbow',
#  'caress',
#  'lucky',
#  'miracle']

# %%
import numpy as np
from gensim.models import KeyedVectors
from nltk.corpus import wordnet as wn

import numpy as np
from nltk.corpus import wordnet as wn

# Ensure you have downloaded the necessary NLTK data
import nltk
nltk.download('wordnet')

def cosine_similarity(embedding1, embedding2):
    norm1 = np.linalg.norm(embedding1)
    norm2 = np.linalg.norm(embedding2)
    return np.dot(embedding1, embedding2) / (norm1 * norm2)

def get_concept_words(word):
    synsets = wn.synsets(word)
    return [lemma.name().replace('_', ' ') for synset in synsets for lemma in synset.lemmas() if synset.pos() in {'n', 'v'}]

def flatten(list_of_lists):
    return [item for sublist in list_of_lists for item in sublist]

def average_embedding(words, embeddings_model):
    valid_embeddings = [embeddings_model.wv[word] for word in words if word in embeddings_model.wv.key_to_index]
    return np.mean(valid_embeddings, axis=0) if valid_embeddings else np.zeros(embeddings_model.vector_size)

# SC-WEAT effect size calculation function with concept words for the target set
def sc_weat_effect_size_target_concepts(target_words, male_words, female_words, embeddings_model, average_score = True):
    # Generate concept words for the target set
    # target_concepts = flatten([get_concept_words(word) for word in target_words])
    word_scweat_dict = []

    # Calculate average embeddings for male and female attribute sets
    male_avg_embedding = average_embedding(male_words, embeddings_model)
    female_avg_embedding = average_embedding(female_words, embeddings_model)

    diffs = []
    for target_word in target_words:
        if target_word in embeddings_model.wv.key_to_index:
            target_embedding = embeddings_model.wv[target_word]
            diff = cosine_similarity(target_embedding, male_avg_embedding) -
                   cosine_similarity(target_embedding, female_avg_embedding)
            diffs.append(diff)

            word_scweat_dict.append({
                'target_word': target_word,
                'scweat_score': diff
            })

    effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
    return (effect_size, word_scweat_dict)

# A positive effect size suggests that the concept words associated with a topic are more closely
# related to the male words than to the female words. This could indicate a male-gendered bias in the context of that topic.


def print_sc_weat_results(topic, score):
    print(f"Topic: {topic}")
    print(f"  SCWEAT effect: {score}")
    print("")


def scweat(male_attributes, female_attributes, target_set, embeddings_model):
  # Define your target and attribute word sets
  male_words = [word for word in male_attributes if word in embeddings_model.wv.key_to_index]
  female_words = [word for word in female_attributes if word in embeddings_model.wv.key_to_index]

  # Create a mapping dictionary to associate topic labels with words
  # topic_words_mapping = {}
  sc_weat_results = {}

  effect_size, word_scweat_scores = sc_weat_effect_size_target_concepts(target_set, male_words, female_words, embeddings_model)
  # sc_weat_results["topic"] = topic_label
  sc_weat_results["effect_size"] = effect_size
  sc_weat_results["word_scores"] = word_scweat_scores

  return sc_weat_results

  # for topic_label in aggregated_lyrics['topic'].unique():
  #     # Logic to obtain top words for each topic
  #     top_words = aggregated_lyrics[(aggregated_lyrics['topic'] == topic_label)]['top_words'].tolist()
  #     top_words = flatten(top_words)
  #     top_words_cleared = [item[0] for item in top_words]
  #     topic_words_mapping[topic_label] = top_words_cleared
  #     target_set=top_words_cleared
  #     topic = get_topic_label(topic_label)

  #     if target_set:
  #         effect_size, word_scweat_scores = sc_weat_effect_size_target_concepts(target_set, male_words, female_words, word_embeddings_model)
  #         print_sc_weat_results(topic,  effect_size)
  #         sc_weat_results.append({
  #             "topic_number": str(topic_label),
  #             "topic_label": topic,
  #             "effect_size": effect_size,
  #             "word_scores": word_scweat_scores
  #         })
  #     else:
  #         print(f"Topic {topic} - Not enough data for SC-WEAT analysis")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
embeddings_path = '/content/drive/MyDrive/Praktikum - NLP Applications/WEAT/embeddings/'

def find_scweat_score(embedding_model):
  results = []

  for target_set_name in target_sets:

    print("Target set:", target_set_name)

    target_set = ast.literal_eval(wordsets[wordsets['set_name'] == target_set_name]['words'].tolist()[0])
    scweat_results = scweat(
        male_attributes=male_attribute_set,
        female_attributes=female_attribute_set,
        target_set=target_set,
        embeddings_model=embedding_model
    )
    results.append({
        "target_set": target_set_name,
        "target_scweat_results": scweat_results
    })

  return results

    # print("\n")

def scweat_for_genre(embeddings_path, genre = None):
  results = []
  if genre is not None:
    embeddings_path += '/' + genre + '/'

  model_list = os.listdir(embeddings_path)

  for model_name in model_list:

    if 'model' not in model_name:
      continue

    print("Topic:", model_name)

    embeddings_model_path = embeddings_path + model_name
    # print(embeddings_model_path)
    embeddings_model = Word2Vec.load(embeddings_model_path)
    scweat_results = find_scweat_score(embeddings_model)

    results.append({
        "topic": model_name.split(".")[0],
        "topic_scweat_results": scweat_results
    })

    print("\n\n")

  return results

# %%
final_results = []
genres = [None, 'country', 'pop', 'rap', 'rb', 'rock']

for genre in genres:
  if genre is None:
    print("Genre: --")

  else:
    print("Genre:", genre)

  genre_results = scweat_for_genre(embeddings_path, genre)
  final_results.append({
      "genre": genre,
      "scweat_results": genre_results
  })
# Out:
# Genre: --
# Topic: nigga_niggas_bitch.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: body_girl_baby.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: tears_heart_wish.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: jesus_praise_lord.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: heartache_bah_bah bah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: ayy ayy_change_long sentiment.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: dance_funky_dance dance.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: em youre_worth em_ahahah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: military time_military_time military.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: solo solo_solo_survive.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Genre: country
# Topic: tears_heart_wish.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: heartache_bah_bah bah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: shes_shell_borderlines.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: country_hank_thats right.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: beautiful beautiful_na_beautiful.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: country_mud_redneck.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: jesus_praise_lord.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: country_party town_want country.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: grandmas hands_grandmas_dad.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: home morning_nah nah_home.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Genre: pop
# Topic: jesus_praise_lord.model
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: tears_heart_wish.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: body_girl_baby.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: heartache_bah_bah bah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: ayy ayy_change_long sentiment.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: dance_funky_dance dance.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: nigga_niggas_bitch.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: solo solo_solo_survive.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: beautiful beautiful_na_beautiful.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: like home_need somebody_home feels.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Genre: rap
# Topic: nigga_niggas_bitch.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: military time_military_time military.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: em youre_worth em_ahahah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: tut_tut tut_aes.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: ra_viral_body body.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: im stickin_stickin im_stickin.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: body_girl_baby.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: dog status_movin rank_status im.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: wanna holler_holler_holler throw.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: mi_dem_yuh.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Genre: rb
# Topic: body_girl_baby.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: love_make love_baby.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: tears_heart_wish.model
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: dance_funky_dance dance.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: heartache_bah_bah bah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: queen black_baby love_love baby.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: ra_viral_body body.model
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: night change_tonight need_wake love.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: comea_stereotype_help wait.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: chicka_chicka boom_boom chicka.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Genre: rock
# Topic: ayy ayy_change_long sentiment.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: shadow_light_moon.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: death unlike_unlike_whoo woahwoah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: sudden felt_moving sound_felt body.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: burn burn_burn_line survive.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: jesus_praise_lord.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: heartache_bah_bah bah.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: black gold_gold black_gold.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: beautiful beautiful_na_beautiful.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
#
#
#
# Topic: river_youth youth_mighty river.model
# Target set: Pleasant
# Target set: Unpleasant
# Target set: Appearance words
# Target set: Intelligence words
# Target set: Strenght words
# Target set: Weakness words
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0
# <ipython-input-40-915a94927beb>:51: RuntimeWarning: divide by zero encountered in float_scalars
#   effect_size = np.mean(diffs) / np.std(diffs) if diffs else 0

# %%
final_results
# Out:
# [{'genre': None,
#   'scweat_results': [{'topic': 'nigga_niggas_bitch',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -0.032685347,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.060518026},
#         {'target_word': 'joy', 'scweat_score': -0.04297009},
#         {'target_word': 'wonderful', 'scweat_score': -0.067364216},
#         {'target_word': 'vacation', 'scweat_score': -0.039269432},
#         {'target_word': 'love', 'scweat_score': -0.09398846},
#         {'target_word': 'honest', 'scweat_score': 0.049852274},
#         {'target_word': 'honor', 'scweat_score': 0.037947595},
#         {'target_word': 'pleasure', 'scweat_score': 0.0220429},
#         {'target_word': 'loyal', 'scweat_score': 0.008782214},
#         {'target_word': 'family', 'scweat_score': -0.01732105},
#         {'target_word': 'peace', 'scweat_score': 0.055117056},
#         {'target_word': 'heaven', 'scweat_score': 0.05906351},
#         {'target_word': 'cheer', 'scweat_score': -0.07018592},
#         {'target_word': 'freedom', 'scweat_score': 0.038792133},
#         {'target_word': 'diploma', 'scweat_score': 0.16544925},
#         {'target_word': 'gentle', 'scweat_score': -0.011764005},
#         {'target_word': 'happy', 'scweat_score': 0.0061285794},
#         {'target_word': 'paradise', 'scweat_score': 0.04033348},
#         {'target_word': 'diamond', 'scweat_score': -0.0048504025},
#         {'target_word': 'laughter', 'scweat_score': -0.01985833},
#         {'target_word': 'sunrise', 'scweat_score': -0.121118516},
#         {'target_word': 'gift', 'scweat_score': 0.09719333},
#         {'target_word': 'health', 'scweat_score': -0.059504002},
#         {'target_word': 'rainbow', 'scweat_score': -0.020752802},
#         {'target_word': 'caress', 'scweat_score': -0.18076375},
#         {'target_word': 'lucky', 'scweat_score': -0.0118980855},
#         {'target_word': 'miracle', 'scweat_score': 0.17376763}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 0.257177,
#        'word_scores': [{'target_word': 'terrible',
#          'scweat_score': 0.021833105},
#         {'target_word': 'prison', 'scweat_score': 0.1408777},
#         {'target_word': 'divorce', 'scweat_score': -0.11158942},
#         {'target_word': 'war', 'scweat_score': 0.12267375},
#         {'target_word': 'poverty', 'scweat_score': 0.050745405},
#         {'target_word': 'sickness', 'scweat_score': -0.016868144},
#         {'target_word': 'abuse', 'scweat_score': -0.058817547},
#         {'target_word': 'tragedy', 'scweat_score': 0.11662164},
#         {'target_word': 'hatred', 'scweat_score': -0.011849135},
#         {'target_word': 'crash', 'scweat_score': -0.094619885},
#         {'target_word': 'accident', 'scweat_score': 0.10403171},
#         {'target_word': 'poison', 'scweat_score': 0.06917627},
#         {'target_word': 'nasty', 'scweat_score': -0.14339224},
#         {'target_word': 'awful', 'scweat_score': 0.02190996},
#         {'target_word': 'grief', 'scweat_score': -0.037153557},
#         {'target_word': 'disaster', 'scweat_score': 0.04021825},
#         {'target_word': 'stink', 'scweat_score': -0.08107},
#         {'target_word': 'pollute', 'scweat_score': -0.04143149},
#         {'target_word': 'ugly', 'scweat_score': -0.074271515},
#         {'target_word': 'rotten', 'scweat_score': -0.046112925},
#         {'target_word': 'filth', 'scweat_score': 0.05529003},
#         {'target_word': 'failure', 'scweat_score': 0.076312676},
#         {'target_word': 'bomb', 'scweat_score': -0.0068114847},
#         {'target_word': 'horrible', 'scweat_score': 0.123902276},
#         {'target_word': 'jail', 'scweat_score': 0.13686015},
#         {'target_word': 'kill', 'scweat_score': 0.025354892},
#         {'target_word': 'cancer', 'scweat_score': 0.08717555},
#         {'target_word': 'death', 'scweat_score': 0.038003534},
#         {'target_word': 'murder', 'scweat_score': 0.044499196},
#         {'target_word': 'evil', 'scweat_score': 0.093867265},
#         {'target_word': 'vomit', 'scweat_score': -0.12543258},
#         {'target_word': 'agony', 'scweat_score': 0.012855396},
#         {'target_word': 'assault', 'scweat_score': 0.16839331}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -0.2701241,
#        'word_scores': [{'target_word': 'sensual', 'scweat_score': -0.00825198},
#         {'target_word': 'thin', 'scweat_score': -0.11599191},
#         {'target_word': 'handsome', 'scweat_score': 0.04970347},
#         {'target_word': 'feeble', 'scweat_score': 0.15083948},
#         {'target_word': 'bald', 'scweat_score': 0.041122433},
#         {'target_word': 'fashionable', 'scweat_score': 0.015920594},
#         {'target_word': 'slim', 'scweat_score': -0.012693942},
#         {'target_word': 'gorgeous', 'scweat_score': -0.103530474},
#         {'target_word': 'fat', 'scweat_score': -0.052176625},
#         {'target_word': 'plump', 'scweat_score': -0.07862678},
#         {'target_word': 'muscular', 'scweat_score': 0.15355936},
#         {'target_word': 'pretty', 'scweat_score': -0.09384832},
#         {'target_word': 'strong', 'scweat_score': 0.06329725},
#         {'target_word': 'weak', 'scweat_score': 0.008639395},
#         {'target_word': 'ugly', 'scweat_score': -0.074271515},
#         {'target_word': 'slender', 'scweat_score': -0.11174804},
#         {'target_word': 'healthy', 'scweat_score': -0.012411743},
#         {'target_word': 'blushing', 'scweat_score': -0.11629477},
#         {'target_word': 'athletic', 'scweat_score': 0.02318129},
#         {'target_word': 'stout', 'scweat_score': -0.055293106},
#         {'target_word': 'beautiful', 'scweat_score': -0.0922606},
#         {'target_word': 'attractive', 'scweat_score': -0.040370837}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': 1.3260016,
#        'word_scores': [{'target_word': 'intelligent',
#          'scweat_score': -0.002471462},
#         {'target_word': 'reflective', 'scweat_score': 0.06157674},
#         {'target_word': 'thoughtful', 'scweat_score': 0.037228875},
#         {'target_word': 'genius', 'scweat_score': 0.19808532},
#         {'target_word': 'logical', 'scweat_score': 0.050224},
#         {'target_word': 'smart', 'scweat_score': 0.045465656},
#         {'target_word': 'shrewd', 'scweat_score': 0.033532225},
#         {'target_word': 'analytical', 'scweat_score': 0.030383743},
#         {'target_word': 'inquiring', 'scweat_score': 0.038039945},
#         {'target_word': 'inquisitive', 'scweat_score': 0.09990845},
#         {'target_word': 'brilliant', 'scweat_score': 0.059732728},
#         {'target_word': 'clever', 'scweat_score': 0.07674385},
#         {'target_word': 'wise', 'scweat_score': 0.13152498}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': 0.81165516,
#        'word_scores': [{'target_word': 'potent', 'scweat_score': 0.02468919},
#         {'target_word': 'bold', 'scweat_score': 0.017182663},
#         {'target_word': 'leader', 'scweat_score': 0.1424606},
#         {'target_word': 'strong', 'scweat_score': 0.06329725},
#         {'target_word': 'triumph', 'scweat_score': 0.05316934},
#         {'target_word': 'command', 'scweat_score': -0.005640745},
#         {'target_word': 'shout', 'scweat_score': 0.042933993},
#         {'target_word': 'winner', 'scweat_score': 0.07318127},
#         {'target_word': 'dominant', 'scweat_score': 0.04027222},
#         {'target_word': 'power', 'scweat_score': 0.0529005},
#         {'target_word': 'succeed', 'scweat_score': -0.03538263},
#         {'target_word': 'confident', 'scweat_score': 0.07547999},
#         {'target_word': 'dynamic', 'scweat_score': 0.15393364},
#         {'target_word': 'loud', 'scweat_score': -0.058244817}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': 0.06926911,
#        'word_scores': [{'target_word': 'loser', 'scweat_score': 0.13882273},
#         {'target_word': 'failure', 'scweat_score': 0.076312676},
#         {'target_word': 'timid', 'scweat_score': -6.146729e-05},
#         {'target_word': 'lose', 'scweat_score': -0.07255989},
#         {'target_word': 'weak', 'scweat_score': 0.008639395},
#         {'target_word': 'weakness', 'scweat_score': -0.038079113},
#         {'target_word': 'shy', 'scweat_score': -0.047048286},
#         {'target_word': 'surrender', 'scweat_score': -0.00027180836},
#         {'target_word': 'follow', 'scweat_score': -0.09010169},
#         {'target_word': 'fragile', 'scweat_score': 0.022343},
#         {'target_word': 'withdraw', 'scweat_score': -0.068367556},
#         {'target_word': 'vulnerable', 'scweat_score': 0.063094236},
#         {'target_word': 'yield', 'scweat_score': -0.04635524},
#         {'target_word': 'afraid', 'scweat_score': 0.12115611}]}}]},
#    {'topic': 'body_girl_baby',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': 0.118184716,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': 0.040159047},
#         {'target_word': 'joy', 'scweat_score': -0.033741638},
#         {'target_word': 'wonderful', 'scweat_score': 0.025626242},
#         {'target_word': 'vacation', 'scweat_score': 0.0054707825},
#         {'target_word': 'love', 'scweat_score': -0.19638722},
#         {'target_word': 'honest', 'scweat_score': 0.008892402},
#         {'target_word': 'honor', 'scweat_score': 0.016574621},
#         {'target_word': 'pleasure', 'scweat_score': 0.035040185},
#         {'target_word': 'loyal', 'scweat_score': 0.056815542},
#         {'target_word': 'family', 'scweat_score': 0.07253435},
#         {'target_word': 'peace', 'scweat_score': 0.06763857},
#         {'target_word': 'heaven', 'scweat_score': 0.057976797},
#         {'target_word': 'cheer', 'scweat_score': -0.014895625},
#         {'target_word': 'freedom', 'scweat_score': -0.08607693},
#         {'target_word': 'diploma', 'scweat_score': 0.041802235},
#         {'target_word': 'gentle', 'scweat_score': 0.05946152},
#         {'target_word': 'happy', 'scweat_score': 0.086393714},
#         {'target_word': 'paradise', 'scweat_score': -0.017628029},
#         {'target_word': 'diamond', 'scweat_score': -0.021643132},
#         {'target_word': 'laughter', 'scweat_score': 0.05684093},
#         {'target_word': 'sunrise', 'scweat_score': 0.0150239},
#         {'target_word': 'gift', 'scweat_score': 0.025837451},
#         {'target_word': 'health', 'scweat_score': -0.03358671},
#         {'target_word': 'rainbow', 'scweat_score': 0.03086257},
#         {'target_word': 'caress', 'scweat_score': -0.10641236},
#         {'target_word': 'lucky', 'scweat_score': -0.05219806},
#         {'target_word': 'miracle', 'scweat_score': 0.056919128}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 0.59220445,
#        'word_scores': [{'target_word': 'terrible',
#          'scweat_score': -0.01801543},
#         {'target_word': 'prison', 'scweat_score': 0.04068341},
#         {'target_word': 'divorce', 'scweat_score': 0.12272537},
#         {'target_word': 'war', 'scweat_score': 0.131638},
#         {'target_word': 'abuse', 'scweat_score': 0.06613603},
#         {'target_word': 'tragedy', 'scweat_score': -0.07064274},
#         {'target_word': 'crash', 'scweat_score': -0.0016900748},
#         {'target_word': 'accident', 'scweat_score': 0.071894616},
#         {'target_word': 'poison', 'scweat_score': 0.020803377},
#         {'target_word': 'nasty', 'scweat_score': -0.077062786},
#         {'target_word': 'awful', 'scweat_score': 0.059899554},
#         {'target_word': 'disaster', 'scweat_score': 0.05684775},
#         {'target_word': 'stink', 'scweat_score': 0.024886504},
#         {'target_word': 'ugly', 'scweat_score': 0.09952776},
#         {'target_word': 'filth', 'scweat_score': 0.010590494},
#         {'target_word': 'bomb', 'scweat_score': -0.062414028},
#         {'target_word': 'horrible', 'scweat_score': 0.03324741},
#         {'target_word': 'jail', 'scweat_score': 0.105091795},
#         {'target_word': 'kill', 'scweat_score': -0.06917695},
#         {'target_word': 'death', 'scweat_score': 0.09876783},
#         {'target_word': 'murder', 'scweat_score': 0.088192634},
#         {'target_word': 'evil', 'scweat_score': 0.09929404}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': 0.60828924,
#        'word_scores': [{'target_word': 'sensual', 'scweat_score': -0.05827886},
#         {'target_word': 'thin', 'scweat_score': 0.032050952},
#         {'target_word': 'handsome', 'scweat_score': 0.096984684},
#         {'target_word': 'bald', 'scweat_score': 0.15781027},
#         {'target_word': 'slim', 'scweat_score': 0.003481388},
#         {'target_word': 'gorgeous', 'scweat_score': 0.038441915},
#         {'target_word': 'fat', 'scweat_score': 0.044953242},
#         {'target_word': 'pretty', 'scweat_score': -0.059912115},
#         {'target_word': 'strong', 'scweat_score': 0.09857727},
#         {'target_word': 'weak', 'scweat_score': 0.09057701},
#         {'target_word': 'ugly', 'scweat_score': 0.09952776},
#         {'target_word': 'healthy', 'scweat_score': 0.008213125},
#         {'target_word': 'blushing', 'scweat_score': 0.090618476},
#         {'target_word': 'beautiful', 'scweat_score': -0.06719677},
#         {'target_word': 'attractive', 'scweat_score': 0.016956016}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': 1.2712458,
#        'word_scores': [{'target_word': 'intelligent',
#          'scweat_score': 0.038426682},
#         {'target_word': 'genius', 'scweat_score': 0.014951706},
#         {'target_word': 'smart', 'scweat_score': 0.070030496},
#         {'target_word': 'brilliant', 'scweat_score': -0.0043485016},
#         {'target_word': 'clever', 'scweat_score': 0.06427637},
#         {'target_word': 'wise', 'scweat_score': 0.115482986}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': 1.1239974,
#        'word_scores': [{'target_word': 'bold', 'scweat_score': 0.06006458},
#         {'target_word': 'leader', 'scweat_score': 0.04650186},
#         {'target_word': 'strong', 'scweat_score': 0.09857727},
#         {'target_word': 'command', 'scweat_score': -0.0072793067},
#         {'target_word': 'shout', 'scweat_score': 0.029376134},
#         {'target_word': 'winner', 'scweat_score': -0.009911478},
#         {'target_word': 'power', 'scweat_score': 0.08047435},
#         {'target_word': 'confident', 'scweat_score': 0.032693535},
#         {'target_word': 'loud', 'scweat_score': 0.019927382}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': 0.124773264,
#        'word_scores': [{'target_word': 'loser', 'scweat_score': 0.18211499},
#         {'target_word': 'lose', 'scweat_score': -0.11190882},
#         {'target_word': 'weak', 'scweat_score': 0.09057701},
#         {'target_word': 'weakness', 'scweat_score': -0.091531485},
#         {'target_word': 'shy', 'scweat_score': 0.009980872},
#         {'target_word': 'surrender', 'scweat_score': 0.013566308},
#         {'target_word': 'follow', 'scweat_score': -0.05707574},
#         {'target_word': 'afraid', 'scweat_score': 0.056250736}]}}]},
#    {'topic': 'tears_heart_wish',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -0.2377492,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.09065959},
#         {'target_word': 'joy', 'scweat_score': -0.03954023},
#         {'target_word': 'wonderful', 'scweat_score': 0.06968549},
#         {'target_word': 'vacation', 'scweat_score': 0.053321764},
#         {'target_word': 'love', 'scweat_score': -0.22387382},
#         {'target_word': 'honest', 'scweat_score': 0.010158867},
#         {'target_word': 'honor', 'scweat_score': 0.014793306},
#         {'target_word': 'pleasure', 'scweat_score': -0.028646931},
#         {'target_word': 'loyal', 'scweat_score': 0.015883174},
#         {'target_word': 'family', 'scweat_score': -0.14136657},
#         {'target_word': 'peace', 'scweat_score': 0.03686802},
#         {'target_word': 'heaven', 'scweat_score': -0.035545766},
#         {'target_word': 'cheer', 'scweat_score': 0.039119408},
#         {'target_word': 'freedom', 'scweat_score': -0.021156609},
#         {'target_word': 'gentle', 'scweat_score': -0.049168617},
#         {'target_word': 'happy', 'scweat_score': -0.046524808},
#         {'target_word': 'paradise', 'scweat_score': -0.010893509},
#         {'target_word': 'diamond', 'scweat_score': -0.03969574},
#         {'target_word': 'laughter', 'scweat_score': -0.035143524},
#         {'target_word': 'sunrise', 'scweat_score': 0.0976568},
#         {'target_word': 'gift', 'scweat_score': 0.07242158},
#         {'target_word': 'health', 'scweat_score': -0.18538365},
#         {'target_word': 'rainbow', 'scweat_score': 0.032020956},
#         {'target_word': 'caress', 'scweat_score': -0.05750829},
#         {'target_word': 'lucky', 'scweat_score': 0.0045758784},
#         {'target_word': 'miracle', 'scweat_score': 0.08432774}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': -0.022293834,
#        'word_scores': [{'target_word': 'terrible',
#          'scweat_score': 0.066612735},
#         {'target_word': 'prison', 'scweat_score': 0.06198165},
#         {'target_word': 'war', 'scweat_score': 0.012718111},
#         {'target_word': 'sickness', 'scweat_score': 0.007883698},
#         {'target_word': 'abuse', 'scweat_score': -0.026585538},
#         {'target_word': 'tragedy', 'scweat_score': -0.0023183823},
#         {'target_word': 'crash', 'scweat_score': -0.07926777},
#         {'target_word': 'poison', 'scweat_score': -0.042211406},
#         {'target_word': 'nasty', 'scweat_score': -0.021412477},
#         {'target_word': 'awful', 'scweat_score': 0.055832505},
#         {'target_word': 'grief', 'scweat_score': -0.08842908},
#         {'target_word': 'disaster', 'scweat_score': 0.08728325},
#         {'target_word': 'ugly', 'scweat_score': -0.056619808},
#         {'target_word': 'failure', 'scweat_score': 0.121489815},
#         {'target_word': 'bomb', 'scweat_score': -0.017327279},
#         {'target_word': 'kill', 'scweat_score': -0.13704258},
#         {'target_word': 'death', 'scweat_score': -0.012557786},
#         {'target_word': 'murder', 'scweat_score': 0.11326876},
#         {'target_word': 'evil', 'scweat_score': -0.07724522},
#         {'target_word': 'agony', 'scweat_score': 0.0036628693}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -0.46412587,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': 0.047847077},
#         {'target_word': 'pretty', 'scweat_score': 0.01917991},
#         {'target_word': 'strong', 'scweat_score': -0.04599473},
#         {'target_word': 'weak', 'scweat_score': -0.02677092},
#         {'target_word': 'ugly', 'scweat_score': -0.056619808},
#         {'target_word': 'beautiful', 'scweat_score': -0.04394266}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': 1.8437792,
#        'word_scores': [{'target_word': 'smart', 'scweat_score': 0.10524775},
#         {'target_word': 'brilliant', 'scweat_score': 0.048097383},
#         {'target_word': 'clever', 'scweat_score': 0.06436609},
#         {'target_word': 'wise', 'scweat_score': 0.016990185}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': -0.03132919,
#        'word_scores': [{'target_word': 'bold', 'scweat_score': 0.111824885},
#         {'target_word': 'strong', 'scweat_score': -0.04599473},
#         {'target_word': 'command', 'scweat_score': -0.09916855},
#         {'target_word': 'shout', 'scweat_score': -0.014418654},
#         {'target_word': 'winner', 'scweat_score': 0.080449805},
#         {'target_word': 'power', 'scweat_score': -0.09227477},
#         {'target_word': 'succeed', 'scweat_score': 0.013861239},
#         {'target_word': 'loud', 'scweat_score': 0.02787061}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -0.436308,
#        'word_scores': [{'target_word': 'loser', 'scweat_score': 0.057265997},
#         {'target_word': 'failure', 'scweat_score': 0.121489815},
#         {'target_word': 'lose', 'scweat_score': -0.22608064},
#         {'target_word': 'weak', 'scweat_score': -0.02677092},
#         {'target_word': 'weakness', 'scweat_score': -0.09272738},
#         {'target_word': 'shy', 'scweat_score': 0.041318804},
#         {'target_word': 'surrender', 'scweat_score': -0.07876274},
#         {'target_word': 'follow', 'scweat_score': -0.14128268},
#         {'target_word': 'fragile', 'scweat_score': -0.0025641918},
#         {'target_word': 'vulnerable', 'scweat_score': -0.07529431},
#         {'target_word': 'afraid', 'scweat_score': -0.021398894}]}}]},
#    {'topic': 'jesus_praise_lord',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -0.06456938,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': 0.12865683},
#         {'target_word': 'joy', 'scweat_score': 0.08590099},
#         {'target_word': 'wonderful', 'scweat_score': 0.10085402},
#         {'target_word': 'love', 'scweat_score': 0.15106742},
#         {'target_word': 'honest', 'scweat_score': -0.09179634},
#         {'target_word': 'honor', 'scweat_score': 0.09426239},
#         {'target_word': 'pleasure', 'scweat_score': 0.027179632},
#         {'target_word': 'family', 'scweat_score': -0.07122034},
#         {'target_word': 'peace', 'scweat_score': 0.10526827},
#         {'target_word': 'heaven', 'scweat_score': 0.09072753},
#         {'target_word': 'cheer', 'scweat_score': -0.08573427},
#         {'target_word': 'freedom', 'scweat_score': 0.05565868},
#         {'target_word': 'gentle', 'scweat_score': -0.18582752},
#         {'target_word': 'happy', 'scweat_score': -0.17878078},
#         {'target_word': 'paradise', 'scweat_score': 0.044913143},
#         {'target_word': 'diamond', 'scweat_score': -0.07185565},
#         {'target_word': 'laughter', 'scweat_score': -0.08996558},
#         {'target_word': 'sunrise', 'scweat_score': -0.10236601},
#         {'target_word': 'gift', 'scweat_score': 0.1992532},
#         {'target_word': 'health', 'scweat_score': -0.012696356},
#         {'target_word': 'rainbow', 'scweat_score': -0.05521421},
#         {'target_word': 'caress', 'scweat_score': -0.21661331},
#         {'target_word': 'lucky', 'scweat_score': -0.1125889},
#         {'target_word': 'miracle', 'scweat_score': 0.016629785}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': -0.6361798,
#        'word_scores': [{'target_word': 'terrible',
#          'scweat_score': -0.04894206},
#         {'target_word': 'prison', 'scweat_score': -0.07942283},
#         {'target_word': 'war', 'scweat_score': 0.07861951},
#         {'target_word': 'poverty', 'scweat_score': -0.110495344},
#         {'target_word': 'sickness', 'scweat_score': -0.022995606},
#         {'target_word': 'abuse', 'scweat_score': -0.123547345},
#         {'target_word': 'tragedy', 'scweat_score': -0.102944866},
#         {'target_word': 'hatred', 'scweat_score': -0.016445428},
#         {'target_word': 'awful', 'scweat_score': -0.03420969},
#         {'target_word': 'grief', 'scweat_score': -0.22459248},
#         {'target_word': 'ugly', 'scweat_score': -0.12924235},
#         {'target_word': 'failure', 'scweat_score': -0.1133917},
#         {'target_word': 'jail', 'scweat_score': -0.18249539},
#         {'target_word': 'kill', 'scweat_score': -0.08377486},
#         {'target_word': 'death', 'scweat_score': 0.21037121},
#         {'target_word': 'evil', 'scweat_score': 0.012892306},
#         {'target_word': 'agony', 'scweat_score': -0.08268168}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -1.1821433,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': -0.20162605},
#         {'target_word': 'feeble', 'scweat_score': -0.17532282},
#         {'target_word': 'pretty', 'scweat_score': -0.1773113},
#         {'target_word': 'strong', 'scweat_score': 0.063703224},
#         {'target_word': 'weak', 'scweat_score': -0.0019626468},
#         {'target_word': 'ugly', 'scweat_score': -0.12924235},
#         {'target_word': 'stout', 'scweat_score': -0.07406789},
#         {'target_word': 'beautiful', 'scweat_score': -0.12719625}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': 3.1014843,
#        'word_scores': [{'target_word': 'brilliant',
#          'scweat_score': 0.03684324},
#         {'target_word': 'wise', 'scweat_score': 0.018877432}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': -0.06201892,
#        'word_scores': [{'target_word': 'bold', 'scweat_score': -0.15929496},
#         {'target_word': 'leader', 'scweat_score': 0.0009486377},
#         {'target_word': 'strong', 'scweat_score': 0.063703224},
#         {'target_word': 'triumph', 'scweat_score': -0.030938167},
#         {'target_word': 'command', 'scweat_score': 0.066535816},
#         {'target_word': 'shout', 'scweat_score': 0.091459185},
#         {'target_word': 'winner', 'scweat_score': -0.08534321},
#         {'target_word': 'power', 'scweat_score': 0.30963224},
#         {'target_word': 'succeed', 'scweat_score': -0.15406545},
#         {'target_word': 'confident', 'scweat_score': 0.0037731752},
#         {'target_word': 'loud', 'scweat_score': -0.20056051}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -0.9255624,
#        'word_scores': [{'target_word': 'failure', 'scweat_score': -0.1133917},
#         {'target_word': 'lose', 'scweat_score': -0.071848564},
#         {'target_word': 'weak', 'scweat_score': -0.0019626468},
#         {'target_word': 'weakness', 'scweat_score': 0.06956069},
#         {'target_word': 'surrender', 'scweat_score': -0.16139528},
#         {'target_word': 'follow', 'scweat_score': 0.012212722},
#         {'target_word': 'fragile', 'scweat_score': -0.17075573},
#         {'target_word': 'yield', 'scweat_score': -0.14341529},
#         {'target_word': 'afraid', 'scweat_score': -0.07981443}]}}]},
#    {'topic': 'heartache_bah_bah bah',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': 0.21128865,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.078696966},
#         {'target_word': 'joy', 'scweat_score': 0.04476314},
#         {'target_word': 'wonderful', 'scweat_score': 0.031304717},
#         {'target_word': 'vacation', 'scweat_score': 0.10109225},
#         {'target_word': 'love', 'scweat_score': -0.15319867},
#         {'target_word': 'honest', 'scweat_score': 0.11076534},
#         {'target_word': 'honor', 'scweat_score': 0.059341073},
#         {'target_word': 'pleasure', 'scweat_score': -0.0017050207},
#         {'target_word': 'family', 'scweat_score': -0.029874742},
#         {'target_word': 'peace', 'scweat_score': -0.051185325},
#         {'target_word': 'heaven', 'scweat_score': 0.11938955},
#         {'target_word': 'freedom', 'scweat_score': -0.14316058},
#         {'target_word': 'gentle', 'scweat_score': 0.04822865},
#         {'target_word': 'happy', 'scweat_score': 0.0092659},
#         {'target_word': 'paradise', 'scweat_score': -0.040262386},
#         {'target_word': 'diamond', 'scweat_score': 0.10301563},
#         {'target_word': 'laughter', 'scweat_score': -0.048090532},
#         {'target_word': 'sunrise', 'scweat_score': 0.15431395},
#         {'target_word': 'gift', 'scweat_score': 0.056096375},
#         {'target_word': 'health', 'scweat_score': -0.039707035},
#         {'target_word': 'rainbow', 'scweat_score': 0.032789648},
#         {'target_word': 'caress', 'scweat_score': 0.029941976},
#         {'target_word': 'lucky', 'scweat_score': -0.001419425},
#         {'target_word': 'miracle', 'scweat_score': 0.08032198}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 0.45284253,
#        'word_scores': [{'target_word': 'terrible', 'scweat_score': 0.05485693},
#         {'target_word': 'prison', 'scweat_score': 0.018225223},
#         {'target_word': 'war', 'scweat_score': 0.036941487},
#         {'target_word': 'abuse', 'scweat_score': -0.07036822},
#         {'target_word': 'tragedy', 'scweat_score': 0.015511125},
#         {'target_word': 'hatred', 'scweat_score': 0.076125965},
#         {'target_word': 'crash', 'scweat_score': 0.09804958},
#         {'target_word': 'poison', 'scweat_score': 0.07678291},
#         {'target_word': 'nasty', 'scweat_score': 0.08732749},
#         {'target_word': 'awful', 'scweat_score': 0.07062556},
#         {'target_word': 'disaster', 'scweat_score': -0.03940785},
#         {'target_word': 'ugly', 'scweat_score': -0.005902186},
#         {'target_word': 'rotten', 'scweat_score': 0.028400864},
#         {'target_word': 'bomb', 'scweat_score': 0.015525922},
#         {'target_word': 'jail', 'scweat_score': 0.13341604},
#         {'target_word': 'kill', 'scweat_score': -0.12254555},
#         {'target_word': 'death', 'scweat_score': -0.041465305},
#         {'target_word': 'murder', 'scweat_score': 0.07428326},
#         {'target_word': 'evil', 'scweat_score': 0.024280112}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -0.03743203,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': 0.099995986},
#         {'target_word': 'fat', 'scweat_score': -0.06886187},
#         {'target_word': 'pretty', 'scweat_score': -0.08455545},
#         {'target_word': 'strong', 'scweat_score': 0.029128313},
#         {'target_word': 'weak', 'scweat_score': 0.005317569},
#         {'target_word': 'ugly', 'scweat_score': -0.005902186},
#         {'target_word': 'healthy', 'scweat_score': 0.02693677},
#         {'target_word': 'beautiful', 'scweat_score': -0.018403947}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': 0.73977613,
#        'word_scores': [{'target_word': 'smart', 'scweat_score': 0.026426658},
#         {'target_word': 'brilliant', 'scweat_score': 0.088459976},
#         {'target_word': 'clever', 'scweat_score': -0.0035219034},
#         {'target_word': 'wise', 'scweat_score': -0.0014572889}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': 0.41330552,
#        'word_scores': [{'target_word': 'bold', 'scweat_score': 0.055392623},
#         {'target_word': 'strong', 'scweat_score': 0.029128313},
#         {'target_word': 'command', 'scweat_score': 0.0949949},
#         {'target_word': 'shout', 'scweat_score': -0.030622866},
#         {'target_word': 'winner', 'scweat_score': 0.05520469},
#         {'target_word': 'power', 'scweat_score': 0.05968578},
#         {'target_word': 'succeed', 'scweat_score': -0.01684578},
#         {'target_word': 'confident', 'scweat_score': -0.076753676},
#         {'target_word': 'dynamic', 'scweat_score': 0.011895761},
#         {'target_word': 'loud', 'scweat_score': 0.016704671}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -0.4851242,
#        'word_scores': [{'target_word': 'loser', 'scweat_score': -0.037058026},
#         {'target_word': 'lose', 'scweat_score': -0.18272486},
#         {'target_word': 'weak', 'scweat_score': 0.005317569},
#         {'target_word': 'weakness', 'scweat_score': 0.1582202},
#         {'target_word': 'shy', 'scweat_score': -0.13157691},
#         {'target_word': 'surrender', 'scweat_score': -0.114482895},
#         {'target_word': 'follow', 'scweat_score': -0.019374017},
#         {'target_word': 'fragile', 'scweat_score': -0.041585073},
#         {'target_word': 'afraid', 'scweat_score': -0.037702978}]}}]},
#    {'topic': 'ayy ayy_change_long sentiment',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -0.019715577,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.04512179},
#         {'target_word': 'joy', 'scweat_score': -0.042101838},
#         {'target_word': 'wonderful', 'scweat_score': -0.01383432},
#         {'target_word': 'vacation', 'scweat_score': 0.03272132},
#         {'target_word': 'love', 'scweat_score': -0.14566724},
#         {'target_word': 'honest', 'scweat_score': 0.08875486},
#         {'target_word': 'honor', 'scweat_score': 0.0224403},
#         {'target_word': 'pleasure', 'scweat_score': -0.043862164},
#         {'target_word': 'loyal', 'scweat_score': -0.02561459},
#         {'target_word': 'family', 'scweat_score': -0.10030636},
#         {'target_word': 'peace', 'scweat_score': 0.020301566},
#         {'target_word': 'heaven', 'scweat_score': 0.09976165},
#         {'target_word': 'cheer', 'scweat_score': 0.057339355},
#         {'target_word': 'freedom', 'scweat_score': 0.047033638},
#         {'target_word': 'gentle', 'scweat_score': 0.042172015},
#         {'target_word': 'happy', 'scweat_score': -0.040286526},
#         {'target_word': 'paradise', 'scweat_score': 0.070814386},
#         {'target_word': 'diamond', 'scweat_score': -0.01589793},
#         {'target_word': 'laughter', 'scweat_score': -0.046955347},
#         {'target_word': 'sunrise', 'scweat_score': -0.0031911135},
#         {'target_word': 'gift', 'scweat_score': 0.075468004},
#         {'target_word': 'health', 'scweat_score': -0.08984083},
#         {'target_word': 'rainbow', 'scweat_score': 0.063816674},
#         {'target_word': 'lucky', 'scweat_score': 0.007422045},
#         {'target_word': 'miracle', 'scweat_score': -0.045588642}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': -0.043403417,
#        'word_scores': [{'target_word': 'terrible',
#          'scweat_score': 0.022929035},
#         {'target_word': 'prison', 'scweat_score': -0.018626869},
#         {'target_word': 'war', 'scweat_score': -0.020642921},
#         {'target_word': 'poverty', 'scweat_score': 0.085065976},
#         {'target_word': 'sickness', 'scweat_score': -0.09469062},
#         {'target_word': 'abuse', 'scweat_score': -0.028733207},
#         {'target_word': 'tragedy', 'scweat_score': 0.032811344},
#         {'target_word': 'hatred', 'scweat_score': -0.063646495},
#         {'target_word': 'crash', 'scweat_score': -0.0371371},
#         {'target_word': 'accident', 'scweat_score': -0.011835903},
#         {'target_word': 'poison', 'scweat_score': -0.03325215},
#         {'target_word': 'nasty', 'scweat_score': 0.01982233},
#         {'target_word': 'awful', 'scweat_score': 0.0026817024},
#         {'target_word': 'grief', 'scweat_score': 0.024439037},
#         {'target_word': 'disaster', 'scweat_score': -0.0031119287},
#         {'target_word': 'ugly', 'scweat_score': -0.047967024},
#         {'target_word': 'rotten', 'scweat_score': 0.03497556},
#         {'target_word': 'failure', 'scweat_score': 0.00014385581},
#         {'target_word': 'bomb', 'scweat_score': -0.025613636},
#         {'target_word': 'horrible', 'scweat_score': 0.027466215},
#         {'target_word': 'jail', 'scweat_score': 0.090854675},
#         {'target_word': 'kill', 'scweat_score': -0.03130685},
#         {'target_word': 'cancer', 'scweat_score': -0.004688531},
#         {'target_word': 'death', 'scweat_score': -0.02498208},
#         {'target_word': 'murder', 'scweat_score': -0.0011528432},
#         {'target_word': 'evil', 'scweat_score': 0.014397524},
#         {'target_word': 'agony', 'scweat_score': 0.044489488}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -0.077631526,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': -0.029149264},
#         {'target_word': 'handsome', 'scweat_score': 0.041075468},
#         {'target_word': 'feeble', 'scweat_score': -0.048527654},
#         {'target_word': 'gorgeous', 'scweat_score': -0.05298063},
#         {'target_word': 'fat', 'scweat_score': 0.014017791},
#         {'target_word': 'pretty', 'scweat_score': -0.006395038},
#         {'target_word': 'strong', 'scweat_score': 0.09115747},
#         {'target_word': 'weak', 'scweat_score': 0.007826954},
#         {'target_word': 'ugly', 'scweat_score': -0.047967024},
#         {'target_word': 'healthy', 'scweat_score': 0.023068309},
#         {'target_word': 'beautiful', 'scweat_score': -0.028380075}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': 0.24147426,
#        'word_scores': [{'target_word': 'thoughtful',
#          'scweat_score': -0.0015037656},
#         {'target_word': 'genius', 'scweat_score': 0.026423842},
#         {'target_word': 'logical', 'scweat_score': 0.033226438},
#         {'target_word': 'smart', 'scweat_score': 0.018220186},
#         {'target_word': 'brilliant', 'scweat_score': -0.030314356},
#         {'target_word': 'clever', 'scweat_score': -0.057065636},
#         {'target_word': 'wise', 'scweat_score': 0.08185464}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': -0.29236832,
#        'word_scores': [{'target_word': 'bold', 'scweat_score': 0.014261425},
#         {'target_word': 'leader', 'scweat_score': 0.011414409},
#         {'target_word': 'strong', 'scweat_score': 0.09115747},
#         {'target_word': 'triumph', 'scweat_score': 0.007987022},
#         {'target_word': 'command', 'scweat_score': -0.071728826},
#         {'target_word': 'shout', 'scweat_score': -0.1003124},
#         {'target_word': 'winner', 'scweat_score': -0.006556958},
#         {'target_word': 'power', 'scweat_score': 0.005627416},
#         {'target_word': 'succeed', 'scweat_score': -0.07508891},
#         {'target_word': 'confident', 'scweat_score': -0.0018464774},
#         {'target_word': 'loud', 'scweat_score': -0.039232884}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -0.22358975,
#        'word_scores': [{'target_word': 'loser', 'scweat_score': 0.037358344},
#         {'target_word': 'failure', 'scweat_score': 0.00014385581},
#         {'target_word': 'lose', 'scweat_score': -0.17258492},
#         {'target_word': 'weak', 'scweat_score': 0.007826954},
#         {'target_word': 'weakness', 'scweat_score': -0.046040803},
#         {'target_word': 'shy', 'scweat_score': 0.044646487},
#         {'target_word': 'surrender', 'scweat_score': -0.07426211},
#         {'target_word': 'follow', 'scweat_score': -0.10182552},
#         {'target_word': 'fragile', 'scweat_score': 0.035322756},
#         {'target_word': 'vulnerable', 'scweat_score': 0.044967584},
#         {'target_word': 'yield', 'scweat_score': -0.001198329},
#         {'target_word': 'afraid', 'scweat_score': 0.045804646}]}}]},
#    {'topic': 'dance_funky_dance dance',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': 0.18947631,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.007808864},
#         {'target_word': 'joy', 'scweat_score': -0.028277114},
#         {'target_word': 'wonderful', 'scweat_score': -0.005951494},
#         {'target_word': 'vacation', 'scweat_score': -0.0060152113},
#         {'target_word': 'love', 'scweat_score': -0.036966413},
#         {'target_word': 'honest', 'scweat_score': 0.007669717},
#         {'target_word': 'pleasure', 'scweat_score': 0.045571536},
#         {'target_word': 'family', 'scweat_score': 0.019951602},
#         {'target_word': 'peace', 'scweat_score': 0.12578753},
#         {'target_word': 'heaven', 'scweat_score': 0.07425173},
#         {'target_word': 'cheer', 'scweat_score': -0.08874213},
#         {'target_word': 'freedom', 'scweat_score': 0.09453972},
#         {'target_word': 'gentle', 'scweat_score': -0.02424746},
#         {'target_word': 'happy', 'scweat_score': 0.032227494},
#         {'target_word': 'paradise', 'scweat_score': 0.039708465},
#         {'target_word': 'diamond', 'scweat_score': -0.08388364},
#         {'target_word': 'laughter', 'scweat_score': 0.07890121},
#         {'target_word': 'sunrise', 'scweat_score': 0.023646392},
#         {'target_word': 'gift', 'scweat_score': 0.06413302},
#         {'target_word': 'health', 'scweat_score': -0.0075071603},
#         {'target_word': 'rainbow', 'scweat_score': 0.15915278},
#         {'target_word': 'caress', 'scweat_score': -0.18764836},
#         {'target_word': 'lucky', 'scweat_score': 0.013166487},
#         {'target_word': 'miracle', 'scweat_score': 0.021224141}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 0.43670505,
#        'word_scores': [{'target_word': 'terrible',
#          'scweat_score': -0.02413711},
#         {'target_word': 'prison', 'scweat_score': 0.013564199},
#         {'target_word': 'war', 'scweat_score': 0.09698425},
#         {'target_word': 'sickness', 'scweat_score': 0.046159267},
#         {'target_word': 'abuse', 'scweat_score': -0.11602879},
#         {'target_word': 'crash', 'scweat_score': 0.0144729465},
#         {'target_word': 'poison', 'scweat_score': 0.0029963404},
#         {'target_word': 'nasty', 'scweat_score': -0.06675327},
#         {'target_word': 'awful', 'scweat_score': 0.10649195},
#         {'target_word': 'disaster', 'scweat_score': 0.017772943},
#         {'target_word': 'stink', 'scweat_score': -0.010249354},
#         {'target_word': 'ugly', 'scweat_score': -0.061901927},
#         {'target_word': 'bomb', 'scweat_score': 0.13636084},
#         {'target_word': 'jail', 'scweat_score': 0.13708998},
#         {'target_word': 'kill', 'scweat_score': 0.03028596},
#         {'target_word': 'cancer', 'scweat_score': 0.038157165},
#         {'target_word': 'death', 'scweat_score': 0.04702702},
#         {'target_word': 'murder', 'scweat_score': 0.06396055},
#         {'target_word': 'evil', 'scweat_score': 0.071739286}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -0.015175424,
#        'word_scores': [{'target_word': 'sensual',
#          'scweat_score': -0.018229358},
#         {'target_word': 'thin', 'scweat_score': 0.007932954},
#         {'target_word': 'handsome', 'scweat_score': 0.02449511},
#         {'target_word': 'bald', 'scweat_score': 0.02773422},
#         {'target_word': 'slim', 'scweat_score': -0.06377259},
#         {'target_word': 'gorgeous', 'scweat_score': 0.09997615},
#         {'target_word': 'fat', 'scweat_score': 0.0022926927},
#         {'target_word': 'pretty', 'scweat_score': -0.07084696},
#         {'target_word': 'strong', 'scweat_score': 0.039281502},
#         {'target_word': 'weak', 'scweat_score': 0.07873967},
#         {'target_word': 'ugly', 'scweat_score': -0.061901927},
#         {'target_word': 'slender', 'scweat_score': -0.08383872},
#         {'target_word': 'healthy', 'scweat_score': 0.00033272803},
#         {'target_word': 'athletic', 'scweat_score': 0.06820283},
#         {'target_word': 'beautiful', 'scweat_score': -0.06328862}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': 0.78605574,
#        'word_scores': [{'target_word': 'genius', 'scweat_score': 0.11445269},
#         {'target_word': 'smart', 'scweat_score': 0.11038588},
#         {'target_word': 'brilliant', 'scweat_score': -0.06545408},
#         {'target_word': 'clever', 'scweat_score': 0.008130198},
#         {'target_word': 'wise', 'scweat_score': 0.13362415}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': 0.24435098,
#        'word_scores': [{'target_word': 'bold', 'scweat_score': -0.048921816},
#         {'target_word': 'leader', 'scweat_score': 0.13554081},
#         {'target_word': 'strong', 'scweat_score': 0.039281502},
#         {'target_word': 'command', 'scweat_score': -0.042113155},
#         {'target_word': 'shout', 'scweat_score': -0.12537745},
#         {'target_word': 'winner', 'scweat_score': -0.05067998},
#         {'target_word': 'power', 'scweat_score': 0.19410203},
#         {'target_word': 'succeed', 'scweat_score': -0.03243359},
#         {'target_word': 'confident', 'scweat_score': 0.07070357},
#         {'target_word': 'loud', 'scweat_score': 0.09035118}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -0.035497997,
#        'word_scores': [{'target_word': 'loser', 'scweat_score': -0.022242256},
#         {'target_word': 'lose', 'scweat_score': 0.025047094},
#         {'target_word': 'weak', 'scweat_score': 0.07873967},
#         {'target_word': 'shy', 'scweat_score': 0.00013288856},
#         {'target_word': 'surrender', 'scweat_score': -0.117519155},
#         {'target_word': 'follow', 'scweat_score': -0.0061318465},
#         {'target_word': 'afraid', 'scweat_score': 0.028065234}]}}]},
#    {'topic': 'em youre_worth em_ahahah',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -0.06335006,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.14610088},
#         {'target_word': 'joy', 'scweat_score': -0.02090795},
#         {'target_word': 'wonderful', 'scweat_score': 0.04497511},
#         {'target_word': 'vacation', 'scweat_score': -0.021359324},
#         {'target_word': 'love', 'scweat_score': -0.15127808},
#         {'target_word': 'honest', 'scweat_score': -0.055062875},
#         {'target_word': 'honor', 'scweat_score': -0.043296576},
#         {'target_word': 'pleasure', 'scweat_score': -0.05453016},
#         {'target_word': 'loyal', 'scweat_score': -0.1537353},
#         {'target_word': 'family', 'scweat_score': -0.040771306},
#         {'target_word': 'peace', 'scweat_score': 0.04862678},
#         {'target_word': 'heaven', 'scweat_score': 0.15142518},
#         {'target_word': 'cheer', 'scweat_score': 0.01593098},
#         {'target_word': 'freedom', 'scweat_score': 0.026649922},
#         {'target_word': 'diploma', 'scweat_score': 0.0016838014},
#         {'target_word': 'happy', 'scweat_score': 0.078947335},
#         {'target_word': 'paradise', 'scweat_score': -0.021466054},
#         {'target_word': 'diamond', 'scweat_score': 0.05368302},
#         {'target_word': 'laughter', 'scweat_score': -0.04596892},
#         {'target_word': 'sunrise', 'scweat_score': -0.037145454},
#         {'target_word': 'gift', 'scweat_score': 0.17031449},
#         {'target_word': 'health', 'scweat_score': -0.10894948},
#         {'target_word': 'rainbow', 'scweat_score': 0.07185194},
#         {'target_word': 'caress', 'scweat_score': -0.025753602},
#         {'target_word': 'lucky', 'scweat_score': -0.020179912},
#         {'target_word': 'miracle', 'scweat_score': 0.14293784}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 0.48142684,
#        'word_scores': [{'target_word': 'terrible',
#          'scweat_score': 0.034907423},
#         {'target_word': 'prison', 'scweat_score': 0.17260781},
#         {'target_word': 'war', 'scweat_score': 0.060228847},
#         {'target_word': 'poverty', 'scweat_score': 0.09211527},
#         {'target_word': 'sickness', 'scweat_score': 0.02359359},
#         {'target_word': 'abuse', 'scweat_score': -0.024297843},
#         {'target_word': 'tragedy', 'scweat_score': 0.04241219},
#         {'target_word': 'crash', 'scweat_score': -0.016655713},
#         {'target_word': 'accident', 'scweat_score': 0.08459291},
#         {'target_word': 'poison', 'scweat_score': 0.058997795},
#         {'target_word': 'nasty', 'scweat_score': -0.058885694},
#         {'target_word': 'awful', 'scweat_score': -0.055120416},
#         {'target_word': 'grief', 'scweat_score': 0.050815135},
#         {'target_word': 'disaster', 'scweat_score': 0.08873369},
#         {'target_word': 'stink', 'scweat_score': 0.015044302},
#         {'target_word': 'ugly', 'scweat_score': 0.03550934},
#         {'target_word': 'rotten', 'scweat_score': 0.06008587},
#         {'target_word': 'failure', 'scweat_score': 0.07949874},
#         {'target_word': 'bomb', 'scweat_score': -0.12231892},
#         {'target_word': 'horrible', 'scweat_score': 0.0777639},
#         {'target_word': 'jail', 'scweat_score': 0.13766086},
#         {'target_word': 'kill', 'scweat_score': 0.0008342713},
#         {'target_word': 'cancer', 'scweat_score': -0.015546523},
#         {'target_word': 'death', 'scweat_score': 0.110251725},
#         {'target_word': 'murder', 'scweat_score': -0.017634805},
#         {'target_word': 'evil', 'scweat_score': -0.008186907},
#         {'target_word': 'vomit', 'scweat_score': -0.08708754},
#         {'target_word': 'agony', 'scweat_score': 0.07134691}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -0.21775027,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': -0.09277505},
#         {'target_word': 'handsome', 'scweat_score': -0.11860037},
# ...
#         {'target_word': 'command', 'scweat_score': 0.02914089},
#         {'target_word': 'shout', 'scweat_score': -0.03751844},
#         {'target_word': 'winner', 'scweat_score': -0.068179965},
#         {'target_word': 'power', 'scweat_score': 0.011955321},
#         {'target_word': 'loud', 'scweat_score': -0.004118085}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -0.35257503,
#        'word_scores': [{'target_word': 'lose', 'scweat_score': -0.058641255},
#         {'target_word': 'weak', 'scweat_score': 0.023062289},
#         {'target_word': 'surrender', 'scweat_score': -0.12629122},
#         {'target_word': 'follow', 'scweat_score': -0.035510123},
#         {'target_word': 'afraid', 'scweat_score': 0.07548207}]}}]},
#    {'topic': 'jesus_praise_lord',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -0.7511439,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': 0.1564945},
#         {'target_word': 'joy', 'scweat_score': -0.09319064},
#         {'target_word': 'wonderful', 'scweat_score': -0.19994685},
#         {'target_word': 'love', 'scweat_score': -0.035136282},
#         {'target_word': 'honor', 'scweat_score': -0.17503561},
#         {'target_word': 'pleasure', 'scweat_score': -0.12640321},
#         {'target_word': 'family', 'scweat_score': -0.062323272},
#         {'target_word': 'peace', 'scweat_score': 0.0055175424},
#         {'target_word': 'heaven', 'scweat_score': 0.08033994},
#         {'target_word': 'freedom', 'scweat_score': -0.12214625},
#         {'target_word': 'happy', 'scweat_score': -0.16526368},
#         {'target_word': 'gift', 'scweat_score': -0.094695866},
#         {'target_word': 'miracle', 'scweat_score': -0.14597344}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 0.017147625,
#        'word_scores': [{'target_word': 'war', 'scweat_score': 0.019129574},
#         {'target_word': 'sickness', 'scweat_score': -0.13063735},
#         {'target_word': 'hatred', 'scweat_score': 0.019207537},
#         {'target_word': 'kill', 'scweat_score': -0.13417262},
#         {'target_word': 'death', 'scweat_score': 0.13693354},
#         {'target_word': 'evil', 'scweat_score': 0.10021317}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -12.593189,
#        'word_scores': [{'target_word': 'strong', 'scweat_score': -0.10130581},
#         {'target_word': 'weak', 'scweat_score': -0.09358829},
#         {'target_word': 'beautiful', 'scweat_score': -0.11341646}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': -6.037375,
#        'word_scores': [{'target_word': 'brilliant',
#          'scweat_score': -0.10857254},
#         {'target_word': 'wise', 'scweat_score': -0.15167934}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': -0.537881,
#        'word_scores': [{'target_word': 'bold', 'scweat_score': -0.063991725},
#         {'target_word': 'strong', 'scweat_score': -0.10130581},
#         {'target_word': 'shout', 'scweat_score': -0.055863574},
#         {'target_word': 'power', 'scweat_score': 0.10773647},
#         {'target_word': 'confident', 'scweat_score': -0.06724417},
#         {'target_word': 'loud', 'scweat_score': -0.036141515}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -2.2928665,
#        'word_scores': [{'target_word': 'lose', 'scweat_score': -0.07229641},
#         {'target_word': 'weak', 'scweat_score': -0.09358829},
#         {'target_word': 'weakness', 'scweat_score': -0.15615368},
#         {'target_word': 'surrender', 'scweat_score': -0.18408576},
#         {'target_word': 'follow', 'scweat_score': -0.08918527},
#         {'target_word': 'yield', 'scweat_score': -0.17412424},
#         {'target_word': 'afraid', 'scweat_score': -0.043795973}]}}]},
#    {'topic': 'heartache_bah_bah bah',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': 0.15381812,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.05170381},
#         {'target_word': 'love', 'scweat_score': -0.15139192},
#         {'target_word': 'honor', 'scweat_score': 0.23290199},
#         {'target_word': 'peace', 'scweat_score': -0.025487423},
#         {'target_word': 'heaven', 'scweat_score': 0.19969371},
#         {'target_word': 'freedom', 'scweat_score': 0.13403615},
#         {'target_word': 'happy', 'scweat_score': -0.00982213},
#         {'target_word': 'paradise', 'scweat_score': 0.037002116},
#         {'target_word': 'lucky', 'scweat_score': 0.039137006},
#         {'target_word': 'miracle', 'scweat_score': -0.199711}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 0.5944251,
#        'word_scores': [{'target_word': 'prison', 'scweat_score': 0.036241233},
#         {'target_word': 'war', 'scweat_score': 0.3240165},
#         {'target_word': 'jail', 'scweat_score': 0.15300769},
#         {'target_word': 'kill', 'scweat_score': -0.21350783},
#         {'target_word': 'death', 'scweat_score': 0.26858094}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': 0.32495314,
#        'word_scores': [{'target_word': 'pretty', 'scweat_score': -0.20893297},
#         {'target_word': 'strong', 'scweat_score': 0.16824183},
#         {'target_word': 'weak', 'scweat_score': 0.1409711},
#         {'target_word': 'beautiful', 'scweat_score': 0.09624404}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': inf,
#        'word_scores': [{'target_word': 'smart', 'scweat_score': 0.12866855}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': 4.070564,
#        'word_scores': [{'target_word': 'strong', 'scweat_score': 0.16824183},
#         {'target_word': 'shout', 'scweat_score': 0.12313965},
#         {'target_word': 'loud', 'scweat_score': 0.22678652}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': 0.8163913,
#        'word_scores': [{'target_word': 'lose', 'scweat_score': -0.08839351},
#         {'target_word': 'weak', 'scweat_score': 0.1409711},
#         {'target_word': 'follow', 'scweat_score': 0.09692377},
#         {'target_word': 'afraid', 'scweat_score': 0.22699861}]}}]},
#    {'topic': 'black gold_gold black_gold',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -2.7144644,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.17431676},
#         {'target_word': 'joy', 'scweat_score': -0.2127437},
#         {'target_word': 'wonderful', 'scweat_score': -0.12223625},
#         {'target_word': 'love', 'scweat_score': -0.084594905},
#         {'target_word': 'honest', 'scweat_score': -0.048514783},
#         {'target_word': 'family', 'scweat_score': -0.22079033},
#         {'target_word': 'peace', 'scweat_score': -0.1120556},
#         {'target_word': 'heaven', 'scweat_score': -0.1286217},
#         {'target_word': 'freedom', 'scweat_score': -0.1540525},
#         {'target_word': 'happy', 'scweat_score': -0.08642268},
#         {'target_word': 'paradise', 'scweat_score': -0.1098125},
#         {'target_word': 'laughter', 'scweat_score': -0.110066},
#         {'target_word': 'health', 'scweat_score': -0.2297476},
#         {'target_word': 'caress', 'scweat_score': -0.18807286},
#         {'target_word': 'lucky', 'scweat_score': -0.18139905}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': -2.5223866,
#        'word_scores': [{'target_word': 'prison', 'scweat_score': -0.18874657},
#         {'target_word': 'war', 'scweat_score': -0.16501155},
#         {'target_word': 'sickness', 'scweat_score': -0.101508915},
#         {'target_word': 'hatred', 'scweat_score': -0.1488421},
#         {'target_word': 'accident', 'scweat_score': -0.22331738},
#         {'target_word': 'poison', 'scweat_score': -0.12322223},
#         {'target_word': 'grief', 'scweat_score': -0.12493223},
#         {'target_word': 'jail', 'scweat_score': -0.16362393},
#         {'target_word': 'kill', 'scweat_score': -0.03789121},
#         {'target_word': 'cancer', 'scweat_score': -0.1956355},
#         {'target_word': 'death', 'scweat_score': -0.08509523},
#         {'target_word': 'murder', 'scweat_score': -0.27723372},
#         {'target_word': 'evil', 'scweat_score': -0.1271292}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -1.5961183,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': -0.16334772},
#         {'target_word': 'pretty', 'scweat_score': -0.1468429},
#         {'target_word': 'strong', 'scweat_score': -0.11615318},
#         {'target_word': 'weak', 'scweat_score': 0.017084002},
#         {'target_word': 'beautiful', 'scweat_score': -0.09765214}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': -26.89768,
#        'word_scores': [{'target_word': 'genius', 'scweat_score': -0.14354724},
#         {'target_word': 'wise', 'scweat_score': -0.13325626}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': -4.6654983,
#        'word_scores': [{'target_word': 'strong', 'scweat_score': -0.11615318},
#         {'target_word': 'command', 'scweat_score': -0.16143084},
#         {'target_word': 'shout', 'scweat_score': -0.10694188},
#         {'target_word': 'power', 'scweat_score': -0.12749511},
#         {'target_word': 'loud', 'scweat_score': -0.18704534}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -1.4810334,
#        'word_scores': [{'target_word': 'loser', 'scweat_score': -0.1910541},
#         {'target_word': 'lose', 'scweat_score': -0.15844592},
#         {'target_word': 'weak', 'scweat_score': 0.017084002},
#         {'target_word': 'surrender', 'scweat_score': -0.0705685},
#         {'target_word': 'follow', 'scweat_score': -0.16469964},
#         {'target_word': 'afraid', 'scweat_score': -0.071383536}]}}]},
#    {'topic': 'beautiful beautiful_na_beautiful',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': 1.3591733,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': 0.07260203},
#         {'target_word': 'joy', 'scweat_score': 0.1189599},
#         {'target_word': 'wonderful', 'scweat_score': 0.10548514},
#         {'target_word': 'love', 'scweat_score': -0.07700279},
#         {'target_word': 'family', 'scweat_score': 0.054153323},
#         {'target_word': 'peace', 'scweat_score': 0.081278324},
#         {'target_word': 'heaven', 'scweat_score': 0.10235351},
#         {'target_word': 'freedom', 'scweat_score': 0.04726094},
#         {'target_word': 'gentle', 'scweat_score': 0.09580469},
#         {'target_word': 'happy', 'scweat_score': 0.007932663},
#         {'target_word': 'laughter', 'scweat_score': 0.1066764},
#         {'target_word': 'sunrise', 'scweat_score': 0.095449924},
#         {'target_word': 'caress', 'scweat_score': 0.1081149}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': 1.53999,
#        'word_scores': [{'target_word': 'war', 'scweat_score': 0.13101286},
#         {'target_word': 'disaster', 'scweat_score': 0.097919166},
#         {'target_word': 'kill', 'scweat_score': -0.00688529},
#         {'target_word': 'death', 'scweat_score': 0.14690644}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': 0.83254325,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': 0.015563071},
#         {'target_word': 'pretty', 'scweat_score': 0.009608507},
#         {'target_word': 'strong', 'scweat_score': -0.0008755326},
#         {'target_word': 'beautiful', 'scweat_score': 0.077061296}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': inf,
#        'word_scores': [{'target_word': 'wise', 'scweat_score': 0.020058215}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': 1.2557522,
#        'word_scores': [{'target_word': 'strong',
#          'scweat_score': -0.0008755326},
#         {'target_word': 'shout', 'scweat_score': 0.07910025},
#         {'target_word': 'power', 'scweat_score': 0.14192194}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -0.9651868,
#        'word_scores': [{'target_word': 'lose', 'scweat_score': -0.056045234},
#         {'target_word': 'follow', 'scweat_score': 0.016623676},
#         {'target_word': 'afraid', 'scweat_score': -0.074252605}]}}]},
#    {'topic': 'river_youth youth_mighty river',
#     'topic_scweat_results': [{'target_set': 'Pleasant',
#       'target_scweat_results': {'effect_size': -1.2373303,
#        'word_scores': [{'target_word': 'friend', 'scweat_score': -0.03636861},
#         {'target_word': 'joy', 'scweat_score': -0.014042914},
#         {'target_word': 'love', 'scweat_score': -0.039500535},
#         {'target_word': 'family', 'scweat_score': -0.03630036},
#         {'target_word': 'peace', 'scweat_score': -0.05131823},
#         {'target_word': 'heaven', 'scweat_score': 0.036343813},
#         {'target_word': 'freedom', 'scweat_score': -0.034738302},
#         {'target_word': 'gentle', 'scweat_score': -0.02188152},
#         {'target_word': 'happy', 'scweat_score': -0.019368947},
#         {'target_word': 'paradise', 'scweat_score': -0.0363912},
#         {'target_word': 'laughter', 'scweat_score': -0.027961314},
#         {'target_word': 'gift', 'scweat_score': -0.0034704208},
#         {'target_word': 'lucky', 'scweat_score': -0.045924008},
#         {'target_word': 'miracle', 'scweat_score': -0.0392552}]}},
#      {'target_set': 'Unpleasant',
#       'target_scweat_results': {'effect_size': -0.987304,
#        'word_scores': [{'target_word': 'prison', 'scweat_score': -0.04657471},
#         {'target_word': 'war', 'scweat_score': -0.041217446},
#         {'target_word': 'sickness', 'scweat_score': -0.011987269},
#         {'target_word': 'hatred', 'scweat_score': -0.026277363},
#         {'target_word': 'poison', 'scweat_score': 0.023379564},
#         {'target_word': 'rotten', 'scweat_score': -0.0035439134},
#         {'target_word': 'failure', 'scweat_score': -0.030957818},
#         {'target_word': 'kill', 'scweat_score': -0.04434961},
#         {'target_word': 'death', 'scweat_score': -0.037183285},
#         {'target_word': 'evil', 'scweat_score': 0.0013543367}]}},
#      {'target_set': 'Appearance words',
#       'target_scweat_results': {'effect_size': -2.0341349,
#        'word_scores': [{'target_word': 'thin', 'scweat_score': -0.034067273},
#         {'target_word': 'pretty', 'scweat_score': -0.06393218},
#         {'target_word': 'strong', 'scweat_score': -0.008057475},
#         {'target_word': 'weak', 'scweat_score': -0.034721553},
#         {'target_word': 'beautiful', 'scweat_score': -0.052752197}]}},
#      {'target_set': 'Intelligence words',
#       'target_scweat_results': {'effect_size': -inf,
#        'word_scores': [{'target_word': 'wise',
#          'scweat_score': -0.041516542}]}},
#      {'target_set': 'Strenght words',
#       'target_scweat_results': {'effect_size': -1.4932256,
#        'word_scores': [{'target_word': 'strong', 'scweat_score': -0.008057475},
#         {'target_word': 'triumph', 'scweat_score': -0.068036675},
#         {'target_word': 'command', 'scweat_score': -0.046761036},
#         {'target_word': 'shout', 'scweat_score': -0.05741316},
#         {'target_word': 'power', 'scweat_score': -0.1176033},
#         {'target_word': 'loud', 'scweat_score': -0.020125508}]}},
#      {'target_set': 'Weakness words',
#       'target_scweat_results': {'effect_size': -1.9166921,
#        'word_scores': [{'target_word': 'failure',
#          'scweat_score': -0.030957818},
#         {'target_word': 'lose', 'scweat_score': 0.0036097765},
#         {'target_word': 'weak', 'scweat_score': -0.034721553},
#         {'target_word': 'surrender', 'scweat_score': -0.041502118},
#         {'target_word': 'follow', 'scweat_score': -0.037023604},
#         {'target_word': 'afraid', 'scweat_score': -0.029951453}]}}]}]}]

# %%
# convert to df

rows = []

# appending rows
for topic in final_results:
    for topic_results in topic['scweat_results']:
      for target_set_results in topic_results['topic_scweat_results']:
        row = {}
        row['genre'] = topic['genre']
        row['topic'] = topic_results['topic']
        row['target_set'] = target_set_results['target_set']
        row['effect_size'] = target_set_results['target_scweat_results']['effect_size']
        row['word_scores'] = target_set_results['target_scweat_results']['word_scores']

        rows.append(row)

results_df = pd.DataFrame(rows)

# %%
weat_results_path = '/content/drive/MyDrive/Praktikum - NLP Applications/WEAT/weat_results.csv'
results_df.to_csv(weat_results_path)
